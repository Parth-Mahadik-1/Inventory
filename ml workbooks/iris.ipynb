# %%
print("hell0")
# Out:
# hell0

# %%
from sklearn import datasets
import pandas as pd

# %%
df = datasets.load_iris()

# %%
dir(df)
df.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df_dataset=pd.DataFrame(df.data,columns=df.feature_names)
df_dataset["target"]=df.target
df_dataset
df_dataset["names"] = df_dataset.target.apply(lambda x:df.target_names[x])
df_dataset
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target      names
# ...

# %%
x = df_dataset.drop(columns=["target", "names"])
x
y = df_dataset.target
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
from sklearn.model_selection import  train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.9)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model .fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict([[5.9,3.0,5.1,1.8]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([2])

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
new  = fig.add_subplot(1, 1, 1)
new.scatter(df_dataset["sepal length (cm)"],df_dataset["sepal width (cm)"],color="green",marker=".")
new.scatter(df_dataset["petal length (cm)"],df_dataset["petal width (cm)"],color="red",marker="+")

# %%
import matplotlib.pyplot as plt
plt.scatter(df_dataset["sepal length (cm)"],df_dataset["sepal width (cm)"],color="green",marker=".")

# %%
import matplotlib.pyplot as plt
plt.scatter(df_dataset["petal length (cm)"],df_dataset["petal width (cm)"],color="red",marker="+")
