# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/colab collection/insurence.csv")

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
from sklearn.model_selection import train_test_split

# %%
x = df[["age"]]

# %%
y = df.bought_insurance

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    1
# 25    1
# 26    0
# Name: bought_insurance, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.9)

# %%
x_test
# Out:
#     age
# 16   25
# 5    56
# 10   18

# %%
y_test
# Out:
# 16    1
# 5     1
# 10    0
# Name: bought_insurance, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg = LogisticRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
reg.predict(x_test)
# Out:
# array([0, 1, 0])

# %%
y_test
# Out:
# 16    1
# 5     1
# 10    0
# Name: bought_insurance, dtype: int64

# %%
reg.score(x_train,y_train)
# Out:
# 0.875

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %%
reg.predict([[35]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import pickle

# %%
with open("my file","wb") as f:
  pickle.dump(reg,f)

# %%
from google.colab import files

# Download the pickle file to your local machine
files.download("my file")
